# %%
# Import dependencies 
import pandas as pd

# %%
# set path to raw data file
rawdata = "Resources/purchase_data.csv"

# %%
# read file into pandas and see what the dataframe looks like
purchase_data = pd.read_csv(rawdata)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
#check if there is any missing data rows
purchase_data.count()
# Out:
# Purchase ID    780
# SN             780
# Age            780
# Gender         780
# Item ID        780
# Item Name      780
# Price          780
# dtype: int64

# %%
#check data types
purchase_data.dtypes
# Out:
# Purchase ID      int64
# SN              object
# Age              int64
# Gender          object
# Item ID          int64
# Item Name       object
# Price          float64
# dtype: object

# %%
#PLAYER COUNT
#calculate the number of total players
totalplayers = purchase_data['SN'].nunique()

#create a DataFrame
totalplayers_df = pd.DataFrame(
    {"Total Players": [totalplayers]})

totalplayers_df
# Out:
#    Total Players
# 0            576

# %%
#PURCHASING ANALYSIS
#calculate number of unique items sold
uniqueitems = purchase_data['Item Name'].nunique()

#calculate average price
averageprice = purchase_data['Price'].mean()

#calculate number of purchases
numpurchases = purchase_data['Purchase ID'].count()

#calculate total revenue
totalrevenue = purchase_data['Price'].sum()

#create a DataFrame
pa_df = pd.DataFrame(
    {"Number of Unique Items": [uniqueitems],
    "Average Price": [averageprice],
    "Number of Purchases": [numpurchases],
    "Total Revenue": [totalrevenue]})

#put data in more proper format
pa_df["Average Price"] = pa_df["Average Price"].map("${:.2f}".format)
pa_df["Total Revenue"] = pa_df["Total Revenue"].map("${:,.2f}".format)

pa_df
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     179         $3.05                  780     $2,379.77

# %%
#create a new data frame that combines all the purchases for each player 
#so you don't have duplicates in sevreal of the lists
players = []
ages = []
genders = []

for i in range(0, len(purchase_data['SN'])):
    if purchase_data['SN'][i] not in players:
        players.append(purchase_data['SN'][i])
        ages.append(purchase_data['Age'][i])
        genders.append(purchase_data['Gender'][i])
        
        
purchase_df = pd.DataFrame(
    {"SN":players,
     "Age":ages,
     "Gender":genders})
#if you want to check this new dataframe
#purchase_df.head()

# %%
#GENDER DEMOGRAPHICS
#check  your total counts
gendercounts = purchase_df['Gender'].value_counts()
gendercounts

#get the values for the males
only_males = purchase_df.loc[purchase_df["Gender"] == "Male", :]
malecount = len(only_males)
malepercent = (len(only_males)/totalplayers)*100

#get the values for the females
only_females = purchase_df.loc[purchase_df["Gender"] == "Female", :]
femalecount = len(only_females)
femalepercent = (len(only_females)/totalplayers)*100

#get the values for the males
only_other = purchase_df.loc[purchase_df["Gender"] == "Other / Non-Disclosed", :]
othercount = len(only_other)
otherpercent = (len(only_other)/totalplayers)*100

#Create a DataFrame
gender_df = pd.DataFrame(
    {"": ["Male", "Female", "Other / Non-Disclosed"],
     "Total Count": [ malecount, femalecount, othercount],
     "Percentage of Players": [ malepercent, femalepercent, otherpercent]})

#put data in more proper format
gender_df["Percentage of Players"] = gender_df["Percentage of Players"].map("{:.2f}%".format)

gender_df
# Out:
#                           Total Count Percentage of Players
# 0                   Male          484                84.03%
# 1                 Female           81                14.06%
# 2  Other / Non-Disclosed           11                 1.91%

# %%
#PURCHASING ANALYSIS GENDER

#calculate number of purchases, add each price to a list
#set the variables to 0 and then loop through data to count occurances and fill lists
malepc = 0
femalepc = 0
otherpc = 0
malepurchases = []
femalepurchases = []
otherpurchases = []

for i in range(0, len(purchase_data['Gender'])):
    if purchase_data['Gender'][i] == "Male":
        malepurchases.append(purchase_data['Price'][i])
        malepc += 1
    elif purchase_data['Gender'][i] == "Female":
        femalepurchases.append(purchase_data['Price'][i])
        femalepc += 1
    elif purchase_data['Gender'][i] == "Other / Non-Disclosed":
        otherpurchases.append(purchase_data['Price'][i])
        otherpc += 1

#get total purchase value for each gender
malesum = sum(malepurchases)
femalesum = sum(femalepurchases)
othersum = sum(otherpurchases)

#calculate average purchase price using purchase count and total purchase value
avgmale = malesum/malepc
avgfemale = femalesum/femalepc
avgother = othersum/otherpc

#use condensed gendercount variables from gender demographics to calculate per person
avgppmale = malesum/malecount
avgppfemale = femalesum/femalecount
avgppother = othersum/othercount

#create Dataframe
ga_df = pd.DataFrame(
    {"Gender": ["Male", "Female", "Other / Non-Disclosed"],
     "Purchase Count": [malepc, femalepc, otherpc],
     "Average Purchase Price": [avgmale, avgfemale, avgother],
     "Total Purchase Value": [malesum, femalesum, othersum],
     "Avg Total Purchase per Person": [avgppmale, avgppfemale, avgppother]})

#put data in more proper format
ga_df["Average Purchase Price"] = ga_df["Average Purchase Price"].map("${:.2f}".format)
ga_df["Total Purchase Value"] = ga_df["Total Purchase Value"].map("${:,.2f}".format)
ga_df["Avg Total Purchase per Person"] = ga_df["Avg Total Purchase per Person"].map("${:.2f}".format)

ga_df
# Out:
#                   Gender  Purchase Count Average Purchase Price  \
# 0                   Male             652                  $3.02
# 1                 Female             113                  $3.20
# 2  Other / Non-Disclosed              15                  $3.35
#
#   Total Purchase Value Avg Total Purchase per Person
# 0            $1,967.64                         $4.07
# 1              $361.94                         $4.47
# 2               $50.19                         $4.56

# %%
#AGE DEMOGRAPHICS

#create the bins to separate the age group and label the bins
bins = [0, 9.9, 14.9, 19.9, 24.9, 29.9, 34.9, 39.9, 100]
bin_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

#add column to dataframe that describes that shows bins
purchase_df["Age Group"] = pd.cut(purchase_df["Age"], bins, labels=bin_names, include_lowest=True)

#calculate total count and percent of total for each group
# Under 10
only1 = purchase_df.loc[purchase_df["Age Group"] == "<10", :]
count1 = len(only1)
percent1 = (len(only1)/totalplayers)*100

# 10 to 14
only2 = purchase_df.loc[purchase_df["Age Group"] == "10-14", :]
count2 = len(only2)
percent2 = (len(only2)/totalplayers)*100

# 15 to 19
only3 = purchase_df.loc[purchase_df["Age Group"] == "15-19", :]
count3 = len(only3)
percent3 = (len(only3)/totalplayers)*100

# 20 to 24
only4 = purchase_df.loc[purchase_df["Age Group"] == "20-24", :]
count4 = len(only4)
percent4 = (len(only4)/totalplayers)*100

# 25 to 29
only5 = purchase_df.loc[purchase_df["Age Group"] == "25-29", :]
count5 = len(only5)
percent5 = (len(only5)/totalplayers)*100

# 30 to 34
only6 = purchase_df.loc[purchase_df["Age Group"] == "30-34", :]
count6 = len(only6)
percent6 = (len(only6)/totalplayers)*100

# 35 to 39
only7 = purchase_df.loc[purchase_df["Age Group"] == "35-39", :]
count7 = len(only7)
percent7 = (len(only7)/totalplayers)*100

# Over 40
only8 = purchase_df.loc[purchase_df["Age Group"] == "40+", :]
count8 = len(only8)
percent8 = (len(only8)/totalplayers)*100

#Create the DataFrame
age_df = pd.DataFrame(
    {"": ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"],
     "Total Count": [ count1, count2, count3, count4, count5, count6, count7, count8],
     "Percentage of Players": [ percent1, percent2, percent3, percent4, percent5, percent6, percent7, percent8]})

#put data in more proper format
age_df["Percentage of Players"] = age_df["Percentage of Players"].map("{:.2f}%".format)

age_df
# Out:
#           Total Count Percentage of Players
# 0    <10           17                 2.95%
# 1  10-14           22                 3.82%
# 2  15-19          107                18.58%
# 3  20-24          258                44.79%
# 4  25-29           77                13.37%
# 5  30-34           52                 9.03%
# 6  35-39           31                 5.38%
# 7    40+           12                 2.08%

# %%
#PURCHASING ANALYSIS AGE
#sort the original dataframe so you get a proper purchase count
#create the bins to separate the age group and label the bins
bins = [0, 9.9, 14.9, 19.9, 24.9, 29.9, 34.9, 39.9, 100]
bin_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

#add column to dataframe that describes that shows bins
purchase_data["Age Group"] = pd.cut(purchase_data["Age"], bins, labels=bin_names, include_lowest=True)

# %%
#calculate number of purchases, add each price to a list
#set the variables to 0 and then loop through data to count occurances and fill lists
pc1 = 0
pc2 = 0
pc3 = 0
pc4 = 0
pc5 = 0
pc6 = 0
pc7 = 0
pc8 = 0
purchases1 = []
purchases2 = []
purchases3 = []
purchases4 = []
purchases5 = []
purchases6 = []
purchases7 = []
purchases8 = []

for i in range(0, len(purchase_data['Age'])):
    if purchase_data['Age Group'][i] == "<10":
        purchases1.append(purchase_data['Price'][i])
        pc1 += 1
    elif purchase_data['Age Group'][i] == "10-14":
        purchases2.append(purchase_data['Price'][i])
        pc2 += 1
    elif purchase_data['Age Group'][i] == "15-19":
        purchases3.append(purchase_data['Price'][i])
        pc3 += 1
    elif purchase_data['Age Group'][i] == "20-24":
        purchases4.append(purchase_data['Price'][i])
        pc4 += 1
    elif purchase_data['Age Group'][i] == "25-29":
        purchases5.append(purchase_data['Price'][i])
        pc5 += 1
    elif purchase_data['Age Group'][i] == "30-34":
        purchases6.append(purchase_data['Price'][i])
        pc6 += 1
    elif purchase_data['Age Group'][i] == "35-39":
        purchases7.append(purchase_data['Price'][i])
        pc7 += 1
    elif purchase_data['Age Group'][i] == "40+":
        purchases8.append(purchase_data['Price'][i])
        pc8 += 1

#get total purchase value for each age group
sum1 = sum(purchases1)
sum2 = sum(purchases2)
sum3 = sum(purchases3)
sum4 = sum(purchases4)
sum5 = sum(purchases5)
sum6 = sum(purchases6)
sum7 = sum(purchases7)
sum8 = sum(purchases8)

#calculate average purchase price using purchase count and total purchase value
avg1 = sum1/pc1
avg2 = sum2/pc2
avg3 = sum3/pc3
avg4 = sum4/pc4
avg5 = sum5/pc5
avg6 = sum6/pc6
avg7 = sum7/pc7
avg8 = sum8/pc8

#use condensed gendercount variables from gender demographics to calculate per person
avgpp1 = sum1/count1
avgpp2 = sum2/count2
avgpp3 = sum3/count3
avgpp4 = sum4/count4
avgpp5 = sum5/count5
avgpp6 = sum6/count6
avgpp7 = sum7/count7
avgpp8 = sum8/count8

#create Dataframe
aa_df = pd.DataFrame(
    {"Age Group": ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"],
     "Purchase Count": [pc1, pc2, pc3, pc4, pc5, pc6, pc7, pc8],
     "Average Purchase Price": [avg1, avg2, avg3, avg4, avg5, avg6, avg7, avg8],
     "Total Purchase Value": [sum1, sum2, sum3, sum4, sum5, sum6, sum7, sum8],
     "Avg Total Purchase per Person": [avgpp1, avgpp2, avgpp3, avgpp4, avgpp5, avgpp6, avgpp7, avgpp8]})

#put data in more proper format
aa_df["Average Purchase Price"] = aa_df["Average Purchase Price"].map("${:.2f}".format)
aa_df["Total Purchase Value"] = aa_df["Total Purchase Value"].map("${:,.2f}".format)
aa_df["Avg Total Purchase per Person"] = aa_df["Avg Total Purchase per Person"].map("${:.2f}".format)

aa_df
# Out:
#   Age Group  Purchase Count Average Purchase Price Total Purchase Value  \
# 0       <10              23                  $3.35               $77.13
# 1     10-14              28                  $2.96               $82.78
# 2     15-19             136                  $3.04              $412.89
# 3     20-24             365                  $3.05            $1,114.06
# 4     25-29             101                  $2.90              $293.00
# 5     30-34              73                  $2.93              $214.00
# 6     35-39              41                  $3.60              $147.67
# 7       40+              13                  $2.94               $38.24
#
#   Avg Total Purchase per Person
# 0                         $4.54
# 1                         $3.76
# 2                         $3.86
# 3                         $4.32
# 4                         $3.81
# 5                         $4.12
# 6                         $4.76
# 7                         $3.19

# %%
#TOP SPENDERS
#retrieve needed columns
spender_data = purchase_data[["SN", "Price"]]

#group by SN
groupedsn = spender_data.groupby(["SN"])
groupedsn.count().head()

#Calculate total purchase for each SN
#will be used to calculate the avergae purchase price later
totalsn = groupedsn["Price"].sum()

#calculate purchase count by counting all rows
countsn = groupedsn["Price"].count()

#start DataFrame
top_df = pd.DataFrame(
    groupedsn["Price"].sum())

#add other columns, calculate item price
top_df["Purchase Count"] = countsn
top_df["Average Purchase Price"] = totalsn/countsn

#organize and rename columns
organizedtop_df = top_df[["Purchase Count", "Average Purchase Price", "Price"]]
renametop_df = organizedtop_df.rename(columns={"Price":"Total Purchase Value"})

#sort data by purchase count
sortedtop_df = renametop_df.sort_values("Total Purchase Value", ascending=False)

#put data in more proper format
sortedtop_df["Average Purchase Price"] = sortedtop_df["Average Purchase Price"].map("${:.2f}".format)
sortedtop_df["Total Purchase Value"] = sortedtop_df["Total Purchase Value"].map("${:.2f}".format)

sortedtop_df.head()
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %%
#MOST POPULAR ITEMS
#retrieve needed columns
item_data = purchase_data[["Item ID", "Item Name", "Price"]]

#group the data by Item Id and Item Name
groupedpurchase = item_data.groupby(["Item ID", "Item Name"])
groupedpurchase.count().head()

#calculate total purchase values by summing the values for each individual price
#we will use this to calculate item price
total_purchase = groupedpurchase["Price"].sum()
total_purchase.head()

#Calculate purchase count by counting all the rows
purchase_count = groupedpurchase["Price"].count()

#start the dataframe
pop_df = pd.DataFrame(
    groupedpurchase["Price"].sum())

#add other desired columns 
#calculate item price using the total and the purchase count
pop_df["Purchase Count"] = purchase_count
pop_df["Item Price"] = total_purchase/purchase_count

#organize and rename columns
organizedpop_df = pop_df[["Purchase Count", "Item Price", "Price"]]
renamepop_df = organizedpop_df.rename(columns={"Price":"Total Purchase Value"})

#sort data by purchase count
sortedpop_df = renamepop_df.sort_values("Purchase Count", ascending=False)

#put data in more proper format
sortedpop_df["Item Price"] = sortedpop_df["Item Price"].map("${:.2f}".format)
sortedpop_df["Total Purchase Value"] = sortedpop_df["Total Purchase Value"].map("${:.2f}".format)

sortedpop_df.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 132     Persuasion                                                 9
# 108     Extraction, Quickblade Of Trembling Hands                  9
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 132     Persuasion                                        $3.22
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
#
#                                                      Total Purchase Value
# Item ID Item Name
# 92      Final Critic                                               $59.99
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 145     Fiery Glass Crusader                                       $41.22
# 132     Persuasion                                                 $28.99
# 108     Extraction, Quickblade Of Trembling Hands                  $31.77

# %%
#MOST PROFITABLE ITEMS
#sort values by total purchase value
sortedprofit_df = renamepop_df.sort_values("Total Purchase Value", ascending=False)

#put data in more proper format
sortedprofit_df["Item Price"] = sortedprofit_df["Item Price"].map("${:.2f}".format)
sortedprofit_df["Total Purchase Value"] = sortedprofit_df["Total Purchase Value"].map("${:.2f}".format)

sortedprofit_df.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 103     Singed Scalpel                                             8
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# 92      Final Critic                                               $59.99
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 82      Nirvana                                                    $44.10
# 145     Fiery Glass Crusader                                       $41.22
# 103     Singed Scalpel                                             $34.80

# %% [markdown]
# Observations
# 1. Within this dataset, Men are the demographic that makes up the majority of in game purchases. They make up for almost 85% of the total purchases. It would be interesting to see what the demographics are for those playing the game, rather than only those who made in-game purchases. Are the demographics as skewed for all players, or are men most of that population too, so that all genders tend to purchase optional in-game stuff at a similar rate?
# 2. If you are looking at age demographics, the largest grouping there are 20–24-year-olds. I would be curious to see even smaller ranges for the ages to see what the distribution within the groups around 20-24.
# 3. When working through the final three tables, I noticed when you are looking at the average price per purchase, those numbers tend to be lower than the listed item prices in the tables that describe the most profitable and most popular. I found that interesting, because the thing that was bought the most was on the expensive side. One would think that more people would splurge on the less expensive stuff.
